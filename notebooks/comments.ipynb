# %% [markdown]
# # Social Media Comments Analysis with LLMs
#
# This notebook demonstrates how to use the Social Media Insights Bot to analyze large volumes of social media comments using Large Language Models (LLMs).
#
# ## Features
# - **Sentiment Analysis**: Classify comments as positive, negative, or neutral
# - **Theme Extraction**: Identify recurring topics and trends
# - **RAG-based Querying**: Ask specific questions about the comments
# - **Batch Processing**: Handle up to 10K comments efficiently
# - **Multiple Data Formats**: Support for CSV, JSON, and Python lists

# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: aiohappyeyeballs==2.6.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 1)) (2.6.1)
# Requirement already satisfied: aiohttp==3.12.13 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 2)) (3.12.13)
# Requirement already satisfied: aiosignal==1.4.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: annotated-types==0.7.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: anyio==4.9.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 5)) (4.9.0)
# Requirement already satisfied: attrs==25.3.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 6)) (25.3.0)
# Requirement already satisfied: certifi==2025.6.15 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 7)) (2025.6.15)
# Requirement already satisfied: charset-normalizer==3.4.2 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 8)) (3.4.2)
# Requirement already satisfied: colorama==0.4.6 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 9)) (0.4.6)
# Requirement already satisfied: dataclasses-json==0.6.7 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 10)) (0.6.7)
# Requirement already satisfied: distro==1.9.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 11)) (1.9.0)
# Requirement already satisfied: frozenlist==1.7.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 12)) (1.7.0)
# Requirement already satisfied: greenlet==3.2.3 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 13)) (3.2.3)
# Requirement already satisfied: h11==0.16.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 14)) (0.16.0)
# Requirement already satisfied: httpcore==1.0.9 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 15)) (1.0.9)
# Requirement already satisfied: httpx==0.28.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 16)) (0.28.1)
# Requirement already satisfied: httpx-sse==0.4.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 17)) (0.4.1)
# Requirement already satisfied: idna==3.10 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 18)) (3.10)
# Requirement already satisfied: Jinja2==3.1.6 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 19)) (3.1.6)
# Requirement already satisfied: jiter==0.10.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 20)) (0.10.0)
# Requirement already satisfied: jq==1.9.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 21)) (1.9.1)
# Requirement already satisfied: jsonpatch==1.33 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 22)) (1.33)
# Requirement already satisfied: jsonpointer==3.0.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 23)) (3.0.0)
# Requirement already satisfied: langchain==0.3.26 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 24)) (0.3.26)
# Requirement already satisfied: langchain-community==0.3.27 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 25)) (0.3.27)
# Requirement already satisfied: langchain-core==0.3.68 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 26)) (0.3.68)
# Requirement already satisfied: langchain-openai==0.3.27 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 27)) (0.3.27)
# Requirement already satisfied: langchain-text-splitters==0.3.8 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 28)) (0.3.8)
# Requirement already satisfied: langsmith==0.4.4 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 29)) (0.4.4)
# Requirement already satisfied: MarkupSafe==3.0.2 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 30)) (3.0.2)
# Requirement already satisfied: marshmallow==3.26.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 31)) (3.26.1)
# Requirement already satisfied: multidict==6.6.3 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 32)) (6.6.3)
# Requirement already satisfied: mypy_extensions==1.1.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 33)) (1.1.0)
# Requirement already satisfied: numpy==2.3.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 34)) (2.3.1)
# Requirement already satisfied: openai==1.93.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 35)) (1.93.0)
# Requirement already satisfied: orjson==3.10.18 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 36)) (3.10.18)
# Requirement already satisfied: packaging==24.2 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 37)) (24.2)
# Requirement already satisfied: propcache==0.3.2 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 38)) (0.3.2)
# Requirement already satisfied: pydantic==2.11.7 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 39)) (2.11.7)
# Requirement already satisfied: pydantic-settings==2.10.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 40)) (2.10.1)
# Requirement already satisfied: pydantic_core==2.33.2 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 41)) (2.33.2)
# Requirement already satisfied: python-dotenv==1.1.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 42)) (1.1.1)
# Requirement already satisfied: PyYAML==6.0.2 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 43)) (6.0.2)
# Requirement already satisfied: regex==2024.11.6 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 44)) (2024.11.6)
# Requirement already satisfied: requests==2.32.4 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 45)) (2.32.4)
# Requirement already satisfied: requests-toolbelt==1.0.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 46)) (1.0.0)
# Requirement already satisfied: sniffio==1.3.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 47)) (1.3.1)
# Requirement already satisfied: SQLAlchemy==2.0.41 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 48)) (2.0.41)
# Requirement already satisfied: tenacity==9.1.2 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 49)) (9.1.2)
# Requirement already satisfied: tiktoken==0.9.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 50)) (0.9.0)
# Requirement already satisfied: tqdm==4.67.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 51)) (4.67.1)
# Requirement already satisfied: typing-inspect==0.9.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 52)) (0.9.0)
# Requirement already satisfied: typing-inspection==0.4.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 53)) (0.4.1)
# Requirement already satisfied: typing_extensions==4.14.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 54)) (4.14.1)
# Requirement already satisfied: urllib3==2.5.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 55)) (2.5.0)
# Requirement already satisfied: yarl==1.20.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 56)) (1.20.1)
# Requirement already satisfied: zstandard==0.23.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 57)) (0.23.0)
# Requirement already satisfied: pandas==2.2.3 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 58)) (2.2.3)
# Requirement already satisfied: langchain-huggingface==0.1.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 59)) (0.1.0)
# Requirement already satisfied: matplotlib>=3.5.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 60)) (3.10.5)
# Requirement already satisfied: seaborn>=0.11.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 61)) (0.13.2)
# Requirement already satisfied: wordcloud>=1.8.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 62)) (1.9.4)
# Requirement already satisfied: chromadb>=1.0.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from -r ../requirements.txt (line 63)) (1.0.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from pandas==2.2.3->-r ../requirements.txt (line 58)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from pandas==2.2.3->-r ../requirements.txt (line 58)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from pandas==2.2.3->-r ../requirements.txt (line 58)) (2025.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from langchain-huggingface==0.1.0->-r ../requirements.txt (line 59)) (0.33.2)
# Requirement already satisfied: sentence-transformers>=2.6.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from langchain-huggingface==0.1.0->-r ../requirements.txt (line 59)) (5.0.0)
# Requirement already satisfied: tokenizers>=0.19.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from langchain-huggingface==0.1.0->-r ../requirements.txt (line 59)) (0.21.2)
# Requirement already satisfied: transformers>=4.39.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from langchain-huggingface==0.1.0->-r ../requirements.txt (line 59)) (4.53.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from matplotlib>=3.5.0->-r ../requirements.txt (line 60)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from matplotlib>=3.5.0->-r ../requirements.txt (line 60)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from matplotlib>=3.5.0->-r ../requirements.txt (line 60)) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from matplotlib>=3.5.0->-r ../requirements.txt (line 60)) (1.4.8)
# Requirement already satisfied: pillow>=8 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from matplotlib>=3.5.0->-r ../requirements.txt (line 60)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from matplotlib>=3.5.0->-r ../requirements.txt (line 60)) (3.2.3)
# Requirement already satisfied: build>=1.0.3 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from chromadb>=1.0.0->-r ../requirements.txt (line 63)) (1.2.2.post1)
# Requirement already satisfied: pybase64>=1.4.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from chromadb>=1.0.0->-r ../requirements.txt (line 63)) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (0.35.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from chromadb>=1.0.0->-r ../requirements.txt (line 63)) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from chromadb>=1.0.0->-r ../requirements.txt (line 63)) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from chromadb>=1.0.0->-r ../requirements.txt (line 63)) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from chromadb>=1.0.0->-r ../requirements.txt (line 63)) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from chromadb>=1.0.0->-r ../requirements.txt (line 63)) (1.34.1)
# Requirement already satisfied: pypika>=0.48.9 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from chromadb>=1.0.0->-r ../requirements.txt (line 63)) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from chromadb>=1.0.0->-r ../requirements.txt (line 63)) (7.7.0)
# Requirement already satisfied: importlib-resources in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from chromadb>=1.0.0->-r ../requirements.txt (line 63)) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from chromadb>=1.0.0->-r ../requirements.txt (line 63)) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from chromadb>=1.0.0->-r ../requirements.txt (line 63)) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from chromadb>=1.0.0->-r ../requirements.txt (line 63)) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from chromadb>=1.0.0->-r ../requirements.txt (line 63)) (33.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from chromadb>=1.0.0->-r ../requirements.txt (line 63)) (5.1.0)
# Requirement already satisfied: rich>=10.11.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from chromadb>=1.0.0->-r ../requirements.txt (line 63)) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from chromadb>=1.0.0->-r ../requirements.txt (line 63)) (4.24.0)
# Requirement already satisfied: six>=1.5 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (1.17.0)
# Requirement already satisfied: backoff>=1.10.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (2.2.1)
# Requirement already satisfied: pyproject_hooks in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from build>=1.0.3->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (1.2.0)
# Requirement already satisfied: filelock in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.1.0->-r ../requirements.txt (line 59)) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.1.0->-r ../requirements.txt (line 59)) (2025.5.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (0.26.0)
# Requirement already satisfied: google-auth>=1.0.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (0.6.1)
# Requirement already satisfied: coloredlogs in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (15.0.1)
# Requirement already satisfied: flatbuffers in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (25.2.10)
# Requirement already satisfied: protobuf in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (5.29.5)
# Requirement already satisfied: sympy in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (0.55b1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from rich>=10.11.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from rich>=10.11.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (0.1.2)
# Requirement already satisfied: torch>=1.11.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface==0.1.0->-r ../requirements.txt (line 59)) (2.7.1)
# Requirement already satisfied: scikit-learn in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface==0.1.0->-r ../requirements.txt (line 59)) (1.7.0)
# Requirement already satisfied: scipy in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface==0.1.0->-r ../requirements.txt (line 59)) (1.16.0)
# Requirement already satisfied: safetensors>=0.4.3 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from transformers>=4.39.0->langchain-huggingface==0.1.0->-r ../requirements.txt (line 59)) (0.5.3)
# Requirement already satisfied: networkx in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.1.0->-r ../requirements.txt (line 59)) (3.5)
# Requirement already satisfied: setuptools in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.1.0->-r ../requirements.txt (line 59)) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from typer>=0.9.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from typer>=0.9.0->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (10.0)
# Requirement already satisfied: pyreadline3 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.0->-r ../requirements.txt (line 63)) (3.5.4)
# Requirement already satisfied: joblib>=1.2.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface==0.1.0->-r ../requirements.txt (line 59)) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\gdrive.melwinjamesp\projects\documentchatbot\chatbot\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface==0.1.0->-r ../requirements.txt (line 59)) (3.6.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: D:\GDrive.melwinjamesp\Projects\DocumentChatBot\chatbot\Scripts\python.exe -m pip install --upgrade pip

# %%
# Setup and imports
import sys
import os
sys.path.append('../src')

import importlib
import tqdm as notebook_tqdm



import pandas as pd
import json
from pprint import pprint
from dotenv import load_dotenv
os.chdir('../')
load_dotenv()


from socialMediaInsightsBot import analyze_social_media_comments, SocialMediaInsightsBot

# %%
file_path = './documents/csv/engagements.csv'

# %%
# Also load CSV data if available
csv_path = file_path
if os.path.exists(csv_path):
    df = pd.read_csv(csv_path)
    print(f"\n Also loaded {len(df)} comments from CSV file")
    print(f"CSV columns: {list(df.columns)}")
    for _ in range(10):
        print(f"Sample CSV comment: '{df.sample(1).iloc[0]['comment_text']}'")
else:
    print(f"\n  CSV file not found at {csv_path}")
    print("We'll use the generated sample comments for demonstration")

# %%
comments  = df.sample(100)['comment_text'].tolist()

# %%
# Run the social media insights analysis
print(" Starting Social Media Comments Analysis...")
print("This may take a few minutes as we process the comments with LLMs")



try:
    # Analyze the sample comments
    results, bot = analyze_social_media_comments(
        data_source=comments,
        source_type='list',
        create_vectorstore=False,
        save_path='../comments_analysis_results.json'
    )
    
    print("\n" + "="*60)
    print("📊 ANALYSIS RESULTS")
    print("="*60)
    
    # Display key metrics
    metadata = results['analysis_metadata']
    sentiment = results['sentiment_analysis']
    themes = results['theme_analysis']
    
    print(f"\n📈 Summary:")
    print(f"  • Total Comments: {metadata['total_comments_analyzed']}")
    print(f"  • Model Used: {metadata['model_used']}")
    print(f"  • Analysis Date: {metadata['analysis_date']}")
    
    print(f"\n💭 Sentiment Analysis:")
    print(f"  • Overall Sentiment: {sentiment['overall_sentiment'].upper()}")
    print(f"  • Positive: {sentiment['sentiment_percentages']['positive']}% ({sentiment['sentiment_distribution']['positive']} comments)")
    print(f"  • Negative: {sentiment['sentiment_percentages']['negative']}% ({sentiment['sentiment_distribution']['negative']} comments)")
    print(f"  • Neutral: {sentiment['sentiment_percentages']['neutral']}% ({sentiment['sentiment_distribution']['neutral']} comments)")
    
    print(f"\n🎯 Top Themes:")
    for i, theme in enumerate(themes['top_themes'][:5], 1):
        print(f"  {i}. {theme['theme']} (frequency: {theme['frequency']})")
    
    print(f"\n🔥 Trending Topics:")
    for i, topic in enumerate(themes['trending_topics'][:5], 1):
        print(f"  {i}. {topic['topic']} ({topic['mentions']} mentions)")
    
    print(f"\n💡 Key Insights:")
    for i, insight in enumerate(themes['unique_insights'][:3], 1):
        print(f"  {i}. {insight}")
    
    print("\n✅ Analysis completed successfully!")
    
except Exception as e:
    print(f"❌ Analysis failed: {e}")
    bot = None
    results = None

# %%
results, bot = analyze_social_media_comments(
      data_source=comments,
      source_type='list',
      create_vectorstore=False,
      save_path='./comments_analysis_results.json'
  )

# %%
from socialMediaInsightsBot import analyze_social_media_comments, SocialMediaInsightsBot
import json
from datetime import datetime
import pandas as pd

def print_section_header(title):
    """Print a formatted section header"""
    print("\n" + "="*70 + f"\n {title}\n" + "="*70)

def print_metrics_summary(metrics_report):
    """Print a formatted summary of key metrics"""
    print_section_header("METRICS OVERVIEW")
    
    metadata = metrics_report.get("report_metadata", {})
    key_metrics = metrics_report.get("key_metrics", {})
    
    print(f"📊 Report Generated: {metadata.get('generated_at', 'N/A')}")
    print(f"📅 Analysis Period: {metadata.get('analysis_period', {}).get('start', 'N/A')} to {metadata.get('analysis_period', {}).get('end', 'N/A')}")
    print(f"💬 Total Comments: {metadata.get('total_comments', 0):,}")
    
    print(f"\n🎯 KEY PERFORMANCE INDICATORS")
    print(f"   • Sentiment Score: {key_metrics.get('sentiment_score', 0)}/100")
    print(f"   • Engagement Score: {key_metrics.get('engagement_score', 0)}/100")
    print(f"   • Topic Diversity: {key_metrics.get('topic_diversity', 0)} unique themes")

def print_temporal_trends(metrics_report):
    """Print temporal trend analysis"""
    print_section_header("TEMPORAL TRENDS ANALYSIS")
    
    engagement_metrics = metrics_report.get("engagement_metrics", {})
    temporal_analysis = engagement_metrics.get("temporal_analysis", {})
    
    if temporal_analysis.get("error"):
        print("❌ No temporal data available for analysis")
        return
    
    volume_trends = temporal_analysis.get("volume_trends", {})
    patterns = temporal_analysis.get("patterns", {})
    
    print(f"📈 VOLUME STATISTICS")
    print(f"   • Daily Average: {volume_trends.get('daily_avg', 0):.1f} comments/day")
    print(f"   • Peak Activity: {volume_trends.get('peak_day', {}).get('count', 0)} comments on {volume_trends.get('peak_day', {}).get('date', 'N/A')}")
    print(f"   • Lowest Activity: {volume_trends.get('lowest_day', {}).get('count', 0)} comments on {volume_trends.get('lowest_day', {}).get('date', 'N/A')}")
    
    print(f"\n⏰ ENGAGEMENT PATTERNS")
    print(f"   • Busiest Day: {patterns.get('busiest_day_of_week', 'N/A')}")
    print(f"   • Peak Hour: {patterns.get('busiest_hour', 'N/A')}:00")

def print_weekly_trends(metrics_report):
    """Print weekly trend breakdown"""
    print_section_header("WEEKLY TRENDS")
    
    weekly_trends = metrics_report.get("engagement_metrics", {}).get("weekly_trends", [])
    
    if not weekly_trends:
        print("❌ No weekly trend data available")
        return
    
    print(f"📅 Recent Weekly Activity (Last {len(weekly_trends)} weeks):\n")
    
    for i, week in enumerate(weekly_trends[-8:], 1):  # Show last 8 weeks
        print(f"   Week {i}: {week['week']}")
        print(f"      • Comments: {week['comment_count']:,}")
        print(f"      • Avg Length: {week['avg_comment_length']:.1f} characters")

def print_topic_trends(metrics_report):
    """Print topic trend analysis"""
    print_section_header("TOPIC TRENDS OVER TIME")
    
    topics_over_time = metrics_report.get("content_insights", {}).get("topic_trends_over_time", [])
    
    if not topics_over_time:
        print("❌ No topic trend data available")
        return
    
    print("📋 Topic Evolution (Recent periods):\n")
    
    # Show last few periods
    for period_data in topics_over_time[-4:]:  # Last 4 periods
        print(f"   Period: {period_data['period']} ({period_data['total_comments']} comments)")
        topics = period_data['topics']
        
        # Sort topics by frequency
        sorted_topics = sorted(topics.items(), key=lambda x: x[1], reverse=True)
        
        for topic, count in sorted_topics[:3]:  # Top 3 topics
            if count > 0:
                percentage = (count / period_data['total_comments']) * 100
                print(f"      • {topic.capitalize()}: {count} mentions ({percentage:.1f}%)")

# %%
# Interactive Querying with RAG
if bot and bot.vectorstore:
    print("🤖 Interactive Query System Demo")
    print("Using RAG (Retrieval Augmented Generation) to answer specific questions about the comments")
    print("-" * 60)
    
    # Sample queries to demonstrate capabilities
    sample_queries = [
        "What are the main complaints from users?",
        "What features do people love most?",
        "Are there any technical issues mentioned?",
        "What do users say about customer service?",
        "What improvements do users suggest?"
    ]
    
    for i, query in enumerate(sample_queries, 1):
        print(f"\n📋 Query {i}: {query}")
        print("🔍 Searching relevant comments...")
        
        try:
            response = bot.query_insights(query, top_k=5)
            print(f"💬 Response: {response}")
        except Exception as e:
            print(f"❌ Error processing query: {e}")
        
        print("-" * 40)
    
    print("\n✨ You can now use bot.query_insights('your question') to ask any question about the comments!")
    
else:
    print("❌ Interactive querying not available - analysis may have failed or vectorstore not created")
    print("Please run the previous cell successfully first")

# %%
print_section_header("SOCIAL MEDIA ENGAGEMENT ANALYSIS")

csv_path = './documents/csv/engagements.csv'

if not os.path.exists(csv_path):
    print(f"❌ File not found: {csv_path}")

print(f"🔍 Analyzing comments from: {csv_path}")


# Load and display basic file info
df = pd.read_csv(csv_path)
print(f"📄 File contains {len(df):,} records")
print(f"📅 Date range: {df['timestamp'].min()} to {df['timestamp'].max()}")

# Check for required columns
required_columns = ['timestamp', 'media_id', 'media_caption', 'comment_text']
missing_columns = [col for col in required_columns if col not in df.columns]



print(f"✅ All required columns present: {required_columns}")

# Perform comprehensive analysis
print("\n🚀 Starting comprehensive analysis...")

results, bot = analyze_social_media_comments(
    data_source=csv_path,
    source_type='csv',
    create_vectorstore=True,
    save_path='./engagements_analysis_results.json',
    generate_trends=True,
    create_visualizations=True
)

# Display results
print_section_header("ANALYSIS RESULTS")

# Basic statistics
sentiment = results.get('sentiment_analysis', {})
theme_analysis = results.get('theme_analysis', {})

print(f"📊 SENTIMENT ANALYSIS")
print(f"   Overall Sentiment: {sentiment.get('overall_sentiment', 'N/A').upper()}")

sentiment_pct = sentiment.get('sentiment_percentages', {})
print(f"   • Positive: {sentiment_pct.get('positive', 0):.1f}%")
print(f"   • Negative: {sentiment_pct.get('negative', 0):.1f}%")
print(f"   • Neutral: {sentiment_pct.get('neutral', 0):.1f}%")

print(f"\n🎯 TOP THEMES")
top_themes = theme_analysis.get('top_themes', [])[:5]
for i, theme in enumerate(top_themes, 1):
    print(f"   {i}. {theme.get('theme', 'N/A')} (frequency: {theme.get('frequency', 0)})")

print(f"\n🔥 TRENDING TOPICS")
trending_topics = theme_analysis.get('trending_topics', [])[:5]
for i, topic in enumerate(trending_topics, 1):
    print(f"   {i}. {topic.get('topic', 'N/A')} ({topic.get('mentions', 0)} mentions)")

# Display metrics report if available
if 'metrics_report' in results:
    metrics_report = results['metrics_report']
    print_metrics_summary(metrics_report)
    print_temporal_trends(metrics_report)
    print_weekly_trends(metrics_report)
    print_topic_trends(metrics_report)

# Executive summary
print_section_header("EXECUTIVE SUMMARY")
print(results.get('executive_summary', 'No executive summary available'))

# Interactive query demonstration
print_section_header("SAMPLE INSIGHTS QUERIES")

if bot and bot.vectorstore:
    sample_queries = [
        "What are customers saying about product quality?",
        "What complaints are most common?",
        "What do people love most about the products?",
        "Are there any delivery or shipping issues mentioned?"
    ]
    
    for query in sample_queries:
        print(f"\n❓ Query: {query}")
        try:
            response = bot.query_insights(query, top_k=3)
            print(f"💡 Response: {response[:200]}...")
        except Exception as e:
            print(f"❌ Error: {e}")

print_section_header("ANALYSIS COMPLETE")
print("📁 Generated Files:")
print("   • engagements_analysis_results.json - Complete analysis results")
print("   • ./reports/engagement_trends.png - Temporal trend visualizations")
print("   • ./reports/comment_wordcloud.png - Word cloud visualization")
print("   • ./vectorstore/chroma_social_comments/ - Vector database for queries")

print(f"\n✨ Analysis completed successfully!")
print(f"📊 Processed {len(df):,} comments with temporal trend analysis")
